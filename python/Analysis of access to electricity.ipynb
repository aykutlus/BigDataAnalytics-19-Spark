# %% [markdown]
# ## Analysis of access to electricity (source: the World Bank)

# %% [markdown]
# The World Bank offers a large amount of open data. In this exercise we will focus on the percentage of population having access to electricity in all the countries of the world from 1960 to 2014.  The data can be obtained from this link: https://data.worldbank.org/indicator/EG.ELC.ACCS.ZS. After selecting the CSV format you will get a zip file containing, among others, these two files:
#
# API_EG.ELC.ACCS.ZS_DS2_en_csv_v2.csv
# Metadata_Country_API_EG.ELC.ACCS.ZS_DS2_en_csv_v2.csv
# After taking a look at the content of these files, write a program named electricityAnalysis.py/java which, given a range of years (e.g., 1970 and 1980), prints on the screen the average number of countries of each of the regions (South Asia, North America, etc.) having at least 99% of electricity for all the years between the indicated range. The output must be ordered in descendent order by the percentage value, and it should look like this example (note: these data are invented):

# %%
# Import requiered libriaries

from pyspark.sql import SparkSession
from pyspark.sql.types import *
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Set spark session
spark_session = SparkSession \
    .builder \
    .getOrCreate()

# %%
# Create struct type to define theirs type

struct_ds = [StructField('CountryName', StringType(),False), \
                       StructField('CountryCode', StringType(), False), \
                       StructField('IndicatorName', StringType(), False), \
                       StructField('IndicatorCode', StringType(), False)]

# %%
for years in range(1960,2018):
    struct_ds.append(StructField("_" +str(years), DoubleType(),False))
    
schema = StructType(struct_ds)

# %%
# Load dataset

dataset = spark_session.read.csv(
        path="/home/master/Descargas/API/API_2.csv",
        sep=",",
        header=True,
        schema=schema)

# %%
dataset.show(25)
# Out:
# +--------------------+------------+--------------------+--------------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------------+----------------+----------------+----------------+
# |         CountryName| CountryCode|       IndicatorName| IndicatorCode| _1960| _1961| _1962| _1963| _1964| _1965| _1966| _1967| _1968| _1969| _1970| _1971| _1972| _1973| _1974| _1975| _1976| _1977| _1978| _1979| _1980| _1981| _1982| _1983| _1984| _1985| _1986| _1987| _1988| _1989| _1990|           _1991|           _1992|           _1993|           _1994|           _1995|           _1996|           _1997|           _1998|           _1999|           _2000|           _2001|           _2002|           _2003|           _2004|           _2005|           _2006|           _2007|           _2008|           _2009|           _2010|           _2011|           _2012|           _2013|         _2014|           _2015|           _2016|           _2017|
# +--------------------+------------+--------------------+--------------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------------+----------------+----------------+----------------+
# |   Last Updated Date|  2020-03-18|                null|          null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|          null|            null|            null|            null|
# |        Country Name|Country Code|      Indicator Name|Indicator Code|1960.0|1961.0|1962.0|1963.0|1964.0|1965.0|1966.0|1967.0|1968.0|1969.0|1970.0|1971.0|1972.0|1973.0|1974.0|1975.0|1976.0|1977.0|1978.0|1979.0|1980.0|1981.0|1982.0|1983.0|1984.0|1985.0|1986.0|1987.0|1988.0|1989.0|1990.0|          1991.0|          1992.0|          1993.0|          1994.0|          1995.0|          1996.0|          1997.0|          1998.0|          1999.0|          2000.0|          2001.0|          2002.0|          2003.0|          2004.0|          2005.0|          2006.0|          2007.0|          2008.0|          2009.0|          2010.0|          2011.0|          2012.0|          2013.0|        2014.0|          2015.0|          2016.0|          2017.0|
# |               Aruba|         ABW|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null| 100.0|99.2768707275391|99.2905883789063|99.3052062988281|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|91.6603980031457|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|93.3562921509542|           100.0|           100.0|           100.0|         100.0|           100.0|           100.0|           100.0|
# |         Afghanistan|         AFG|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            23.0|26.9293174743652|33.0157508850098|            42.4|45.2371215820313|            42.7|43.2220189082037|            69.1|70.1534805297852|          89.5|            71.5|            97.7|            97.7|
# |              Angola|         AGO|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|
Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null| 100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|         100.0|           100.0|           100.0|           100.0|
# |             Bahrain|         BHR|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|            null|            null|            null|            null|            null|            null|            null|            null|            null|            null|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|         100.0|           100.0|           100.0|           100.0|
# |        Bahamas, The|         BHS|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null| 100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|       96.065547|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|         100.0|           100.0|           100.0|           100.0|
# |Bosnia and Herzeg...|         BIH|Access to electri...|EG.ELC.ACCS.ZS|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null|  null| 100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|           100.0|            99.4|            98.5|           100.0|           100.0|           100.0|99.3872769868445|            99.7|           100.0|           100.0|           100.0| 99.705780546902|           100.0|           100.0|         100.0|           100.0|           100.0|           100.0|
# +--------------------+------------+--------------------+--------------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------------+----------------+----------------+----------------+
# only showing top 25 rows

# %%
# Load second dataset

dataset2 = spark_session.read.csv(
        path="/home/master/Descargas/API/Metadata_Country.csv",
        sep=",",
        header=True)

# %%
dataset2.show(2)
# Out:
# +------------+--------------------+-----------+------------+-----------+----+
# |Country Code|              Region|IncomeGroup|SpecialNotes|  TableName| _c5|
# +------------+--------------------+-----------+------------+-----------+----+
# |         ABW|Latin America & C...|High income|        null|      Aruba|null|
# |         AFG|          South Asia| Low income|        null|Afghanistan|null|
# +------------+--------------------+-----------+------------+-----------+----+
# only showing top 2 rows

# %%
# Join two datasets on their common column.

dataset_complete = dataset.join(dataset2,dataset["CountryCode"] == dataset2["Country Code"])

# %%
display((dataset_complete).toPandas())
# Out:
#                                            CountryName CountryCode  \
# 0                                                Aruba         ABW
# 1                                          Afghanistan         AFG
# 2                                               Angola         AGO
# 3                                              Albania         ALB
# 4                                              Andorra         AND
# 5                                           Arab World         ARB
# 6                                 United Arab Emirates         ARE
# 7                                            Argentina         ARG
# 8                                              Armenia         ARM
# 9                                       American Samoa         ASM
# 10                                 Antigua and Barbuda         ATG
# 11                                           Australia         AUS
# 12                                             Austria         AUT
# 13                                          Azerbaijan         AZE
# 14                                             Burundi         BDI
# 15                                             Belgium         BEL
# 16                                               Benin         BEN
# 17                                        Burkina Faso         BFA
# 18                                          Bangladesh         BGD
# 19                                            Bulgaria         BGR
# 20                                             Bahrain         BHR
# 21                                        Bahamas, The         BHS
# 22                              Bosnia and Herzegovina         BIH
# 23                                             Belarus         BLR
# 24                                              Belize         BLZ
# 25                                             Bermuda         BMU
# 26                                             Bolivia         BOL
# 27                                              Brazil         BRA
# 28                                            Barbados         BRB
# 29                                   Brunei Darussalam         BRN
# ..                                                 ...         ...
# 233  Latin America & the Caribbean (IDA & IBRD coun...         TLA
# 234                                        Timor-Leste         TLS
# 235  Middle East & North Africa (IDA & IBRD countries)         TMN
# 236                                              Tonga         TON
# 237                            South Asia (IDA & IBRD)         TSA
# 238          Sub-Saharan Africa (IDA & IBRD countries)         TSS
# 239                                Trinidad and Tobago         TTO
# 240                                            Tunisia         TUN
# 241                                             Turkey         TUR
# 242                                             Tuvalu         TUV
# 243                                           Tanzania         TZA
# 244                                             Uganda         UGA
# 245                                            Ukraine         UKR
# 246                                Upper middle income         UMC
# 247                                            Uruguay         URY
# 248                                      United States         USA
# 249                                         Uzbekistan         UZB
# 250                     St. Vincent and the Grenadines         VCT
# 251                                      Venezuela, RB         VEN
# 252                             British Virgin Islands         VGB
# 253                              Virgin Islands (U.S.)         VIR
# 254                                            Vietnam         VNM
# 255                                            Vanuatu         VUT
# 256                                              World         WLD
# 257                                              Samoa         WSM
# 258                                             Kosovo         XKX
# 259                                        Yemen, Rep.         YEM
# 260                                       South Africa         ZAF
# 261                                             Zambia         ZMB
# 262                                           Zimbabwe         ZWE
#
#                                IndicatorName   IndicatorCode _1960 _1961  \
# 0    Access to electricity (% of population)  EG.ELC.ACCS.ZS  None  None
#
# 240  None  None  None  None  ...    99.800000  100.000000  100.000000
# 241  None  None  None  None  ...   100.000000  100.000000  100.000000
# 242  None  None  None  None  ...    98.684448   99.170471   99.665222
# 243  None  None  None  None  ...    23.500000   26.573870   32.800000
# 244  None  None  None  None  ...    20.400000   18.500000   26.700000
# 245  None  None  None  None  ...   100.000000  100.000000  100.000000
# 246  None  None  None  None  ...    99.149444   99.191467   99.231728
# 247  None  None  None  None  ...    99.657085   99.709480   99.700000
# 248  None  None  None  None  ...   100.000000  100.000000  100.000000
# 249  None  None  None  None  ...    99.980331   99.998055  100.000000
# 250  None  None  None  None  ...    98.543213   99.452316   99.908951
# 251  None  None  None  None  ...    99.542747   99.840309   99.967598
# 252  None  None  None  None  ...    99.316460  100.000000  100.000000
# 253  None  None  None  None  ...   100.000000  100.000000  100.000000
# 254  None  None  None  None  ...    99.200000  100.000000  100.000000
# 255  None  None  None  None  ...    43.171406   48.422855   57.820000
# 256  None  None  None  None  ...    85.606673   86.797401   87.995487
# 257  None  None  None  None  ...    97.900000   99.501366   99.783936
# 258  None  None  None  None  ...   100.000000  100.000000  100.000000
# 259  None  None  None  None  ...    66.100000   74.268372   76.066811
# 260  None  None  None  None  ...    86.000000   85.500000   84.200000
# 261  None  None  None  None  ...    27.900000   31.100000   35.216507
# 262  None  None  None  None  ...    32.300000   33.700000   39.892345
#
#           _2017 Country Code                      Region          IncomeGroup  \
# 0    100.000000          ABW   Latin America & Caribbean          High income
# 1     97.700000          AFG                  South Asia           Low income
# 2     41.886230          AGO          Sub-Saharan Africa  Lower middle income
# 3    100.000000          ALB       Europe & Central Asia  Upper middle income
# 4    100.000000          AND       Europe & Central Asia          High income
# 5     90.273687          ARB                        None                 None
# 6    100.000000          ARE  Middle East & North Africa          High income
# 7    100.000000          ARG   Latin America & Caribbean  Upper middle income
# 8    100.000000          ARM       Europe & Central Asia  Upper middle income
# 9           NaN          ASM         East Asia & Pacific  Upper middle income
# 10   100.000000          ATG   Latin America & Caribbean          High income
# 11   100.000000          AUS         East Asia & Pacific          High income
# 12   100.000000          AUT       Europe & Central Asia          High income
# 13   100.000000          AZE       Europe & Central Asia  Upper middle income
# 14     9.300000          BDI          Sub-Saharan Africa           Low income
# 15   100.000000          BEL       Europe & Central Asia          High income
# 16    43.077747          BEN          Sub-Saharan Africa           Low income
# 17    25.473743          BFA          Sub-Saharan Africa           Low income
# 18    88.000000          BGD                  South Asia  Lower middle income
# 19   100.000000          BGR       Europe & Central Asia  Upper middle income
# 20   100.000000          BHR  Middle East & North Africa          High income
# 21   100.000000          BHS   Latin America & Caribbean          High income
# 22   100.000000          BIH       Europe & Central Asia  Upper middle income
# 23   100.000000          BLR       Europe & Central Asia  Upper middle income
# 24    98.265121          BLZ   Latin America & Caribbean  Upper middle income
# 25   100.000000          BMU               North America          High income
# 26    91.800000          BOL   Latin America & Caribbean  Lower middle income
# 27   100.000000          BRA   Latin America & Caribbean  Upper middle income
# 28   100.000000          BRB   Latin America & Caribbean          High income
# 29   100.000000          BRN         East Asia & Pacific          High income
# ..          ...          ...                         ...                  ...
# 233   98.077613          TLA                        None                 None
# 234   80.380753          TLS         East Asia & Pacific  Lower middle income
# 235   97.339822          TMN                        None                 None
# 236   97.967590          TON         East Asia & Pacific  Upper middle income
# 237   89.886489          TSA                        None                 None
# 238   44.573587          TSS                        None                 None
# 239  100.000000          TTO   Latin America & Caribbean          High income
# 240  100.000000          TUN  Middle East & North Africa  Lower middle income
# 241  100.000000          TUR       Europe & Central Asia  Upper middle income
# 242  100.000000          TUV         East Asia & Pacific  Upper middle income
# 243   32.813332          TZA          Sub-Saharan Africa           Low income
# 244   22.000000          UGA          Sub-Saharan Africa           Low income
# 245  100.000000          UKR       Europe & Central Asia  Lower middle income
# 246   99.368574          UMC                        None                 None
# 247  100.000000          URY   Latin America & Caribbean          High income
# 248  100.000000          USA               North America          High income
# 249  100.000000          UZB       Europe & Central Asia  Lower middle income
# 250  100.000000          VCT   Latin America & Caribbean  Upper middle income
# 251  100.000000          VEN   Latin America & Caribbean  Upper middle income
# 252  100.000000          VGB   Latin America & Caribbean          High income
# 253  100.000000          VIR   Latin America & Caribbean          High income
# 254  100.000000          VNM         East Asia & Pacific  Lower middle income
# 255   62.784294          VUT         East Asia & Pacific  Lower middle income
# 256   88.867073          WLD                        None                 None
# 257   96.800000          WSM         East Asia & Pacific  Upper middle income
# 258  100.000000          XKX       Europe & Central Asia  Upper middle income
# 259   79.200000          YEM  Middle East & North Africa           Low income
# 260   84.400000          ZAF          Sub-Saharan Africa  Upper middle income
# 261   40.300000          ZMB          Sub-Saharan Africa  Lower middle income
# 262   40.421368          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5    Arab World aggregate. Arab World is composed o...
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11   Fiscal year end: June 30; reporting period for...
# 12   A simple multiplier is used to convert the nat...
# 13                                                None
# 14                                                None
# 15   A simple multiplier is used to convert the nat...
# 16                                                None
# 17                                                None
# 18   Fiscal year end: June 30; reporting period for...
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23   Data before 2015 were adjusted to reflect the ...
# 24                                                None
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# ..                                                 ...
# 233  Latin America & the Caribbean (IDA & IBRD coun...
# 234                                               None
# 235  Middle East & North Africa (IDA & IBRD countri...
# 236                                               None
# 237       South Asia (IDA & IBRD countries) aggregate.
# 238  Sub-Saharan Africa (IDA & IBRD countries) aggr...
# 239                                               None
# 240                                               None
# 241                                               None
# 242                                               None
# 243                                               None
# 244  Fiscal year end: June 30; reporting period for...
# 245                                               None
# 246  Upper middle income group aggregate. Upper-mid...
# 247                                               None
# 248                                               None
# 249                                               None
# 250                                               None
# 251                                               None
# 252                                               None
# 253                                               None
# 254                                               None
# 255                                               None
# 256                                   World aggregate.
# 257  Fiscal year ends on June 30; reporting period ...
# 258                                               None
# 259                                               None
# 260  Fiscal year end: March 31; reporting period fo...
# 261  National accounts data were rebased to reflect...
# 262                                               None
#
#                                    TableName   _c5
# 0                                      Aruba  None
# 1                                Afghanistan  None
# 2                                     Angola  None
# 3                                    Albania  None
# 4                                    Andorra  None
# 5                                 Arab World  None
# 6                       United Arab Emirates  None
# 7                                  Argentina  None
# 8                                    Armenia  None
# 9                             American Samoa  None
# 10                       Antigua and Barbuda  None
# 11                                 Australia  None
# 12                                   Austria  None
# 13                                Azerbaijan  None
# 14                                   Burundi  None
# 15                                   Belgium  None
# 16                                     Benin  None
# 17                              Burkina Faso  None
# 18                                Bangladesh  None
# 19                                  Bulgaria  None
# 20                                   Bahrain  None
# 21                              Bahamas, The  None
# 22                    Bosnia and Herzegovina  None
# 23                                   Belarus  None
# 24                                    Belize  None
# 25                                   Bermuda  None
# 26                                   Bolivia  None
# 27                                    Brazil  None
# 28                                  Barbados  None
# 29                         Brunei Darussalam  None
# ..                                       ...   ...
# 233   Latin America & Caribbean (IDA & IBRD)  None
# 234                              Timor-Leste  None
# 235  Middle East & North Africa (IDA & IBRD)  None
# 236                                    Tonga  None
# 237                  South Asia (IDA & IBRD)  None
# 238          Sub-Saharan Africa (IDA & IBRD)  None
# 239                      Trinidad and Tobago  None
# 240                                  Tunisia  None
# 241                                   Turkey  None
# 242                                   Tuvalu  None
# 243                                 Tanzania  None
# 244                                   Uganda  None
# 245                                  Ukraine  None
# 246                      Upper middle income  None
# 247                                  Uruguay  None
# 248                            United States  None
# 249                               Uzbekistan  None
# 250           St. Vincent and the Grenadines  None
# 251                            Venezuela, RB  None
# 252                   British Virgin Islands  None
# 253                    Virgin Islands (U.S.)  None
# 254                                  Vietnam  None
# 255                                  Vanuatu  None
# 256                                    World  None
# 257                                    Samoa  None
# 258                                   Kosovo  None
# 259                              Yemen, Rep.  None
# 260                             South Africa  None
# 261                                   Zambia  None
# 262                                 Zimbabwe  None
#
# [263 rows x 68 columns]

# %%
# Check the types are correct
dataset_complete.printSchema()
# Out:
# root
#  |-- CountryName: string (nullable = true)
#  |-- CountryCode: string (nullable = true)
#  |-- IndicatorName: string (nullable = true)
#  |-- IndicatorCode: string (nullable = true)
#  |-- _1960: double (nullable = true)
#  |-- _1961: double (nullable = true)
#  |-- _1962: double (nullable = true)
#  |-- _1963: double (nullable = true)
#  |-- _1964: double (nullable = true)
#  |-- _1965: double (nullable = true)
#  |-- _1966: double (nullable = true)
#  |-- _1967: double (nullable = true)
#  |-- _1968: double (nullable = true)
#  |-- _1969: double (nullable = true)
#  |-- _1970: double (nullable = true)
#  |-- _1971: double (nullable = true)
#  |-- _1972: double (nullable = true)
#  |-- _1973: double (nullable = true)
#  |-- _1974: double (nullable = true)
#  |-- _1975: double (nullable = true)
#  |-- _1976: double (nullable = true)
#  |-- _1977: double (nullable = true)
#  |-- _1978: double (nullable = true)
#  |-- _1979: double (nullable = true)
#  |-- _1980: double (nullable = true)
#  |-- _1981: double (nullable = true)
#  |-- _1982: double (nullable = true)
#  |-- _1983: double (nullable = true)
#  |-- _1984: double (nullable = true)
#  |-- _1985: double (nullable = true)
#  |-- _1986: double (nullable = true)
#  |-- _1987: double (nullable = true)
#  |-- _1988: double (nullable = true)
#  |-- _1989: double (nullable = true)
#  |-- _1990: double (nullable = true)
#  |-- _1991: double (nullable = true)
#  |-- _1992: double (nullable = true)
#  |-- _1993: double (nullable = true)
#  |-- _1994: double (nullable = true)
#  |-- _1995: double (nullable = true)
#  |-- _1996: double (nullable = true)
#  |-- _1997: double (nullable = true)
#  |-- _1998: double (nullable = true)
#  |-- _1999: double (nullable = true)
#  |-- _2000: double (nullable = true)
#  |-- _2001: double (nullable = true)
#  |-- _2002: double (nullable = true)
#  |-- _2003: double (nullable = true)
#  |-- _2004: double (nullable = true)
#  |-- _2005: double (nullable = true)
#  |-- _2006: double (nullable = true)
#  |-- _2007: double (nullable = true)
#  |-- _2008: double (nullable = true)
#  |-- _2009: double (nullable = true)
#  |-- _2010: double (nullable = true)
#  |-- _2011: double (nullable = true)
#  |-- _2012: double (nullable = true)
#  |-- _2013: double (nullable = true)
#  |-- _2014: double (nullable = true)
#  |-- _2015: double (nullable = true)
#  |-- _2016: double (nullable = true)
#  |-- _2017: double (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- IncomeGroup: string (nullable = true)
#  |-- SpecialNotes: string (nullable = true)
#  |-- TableName: string (nullable = true)
#  |-- _c5: string (nullable = true)

# %%
# Take input from keyboard for year range

start_year = int(input("Write a start year "))
end_year = int(input("Write a end year "))
# Out:
# Write a start year 1999
# Write a end year 2007

# %%
years=[]

# %%
# Create years for sql query
for year in range(start_year,end_year): 
    years.append("_{} >= 99 AND ".format(year))

# %%
# Make years string
year_formatted=(str(years)[1:-1].replace("'"," " )).replace(",","" )

# %%
year_formatted
# Out:
# ' _1999 >= 99 AND    _2000 >= 99 AND    _2001 >= 99 AND    _2002 >= 99 AND    _2003 >= 99 AND    _2004 >= 99 AND    _2005 >= 99 AND    _2006 >= 99 AND  '

# %%
# Make queries for two cases, which are regions' countries whose population have an access to electricity 
# more than 99%  and number of countries per region in order to calculate % of electricity access

dataset_complete.createOrReplaceTempView("table2")

df_99  = spark_session.sql("SELECT Region,Count(CountryName) as number from table2 where "+ year_formatted + " Region IS NOT NULL GROUP BY Region" ).toPandas()

df = spark_session.sql("SELECT Region,Count(CountryName) as number from table2 where Region IS NOT NULL GROUP BY Region" ).toPandas()

# %%
df_99
# Out:
#                        Region  number
# 0       Europe & Central Asia      48
# 1               North America       3
# 2         East Asia & Pacific      12
# 3  Middle East & North Africa       5
# 4   Latin America & Caribbean       3

# %%
df
# Out:
#                        Region  number
# 0                  South Asia       8
# 1          Sub-Saharan Africa      48
# 2       Europe & Central Asia      58
# 3               North America       3
# 4         East Asia & Pacific      37
# 5  Middle East & North Africa      21
# 6   Latin America & Caribbean      42

# %%
# Merge two dataframe

df_merged =pd.merge(df_99, df, left_on='Region', right_on='Region', how='left')

# %%
df_merged
# Out:
#                        Region  number_x  number_y  Percentage
# 0       Europe & Central Asia        48        58        83.0
# 1               North America         3         3       100.0
# 2         East Asia & Pacific        12        37        32.0
# 3  Middle East & North Africa         5        21        24.0
# 4   Latin America & Caribbean         3        42         7.0

# %%
# Calculate percentage and prepare format

df_merged["Percentage"] = round(df_merged["number_x"]/df_merged["number_y"].div(100),0)
df_end = df_merged[["Region","Percentage"]].sort_values(by=["Percentage"], ascending=False)
df_end["Percentage"] = df_end["Percentage"].astype(str) + '%'
df_end
# Out:
#                        Region Percentage
# 1               North America     100.0%
# 0       Europe & Central Asia      83.0%
# 2         East Asia & Pacific      32.0%
# 3  Middle East & North Africa      24.0%
# 4   Latin America & Caribbean       7.0%
